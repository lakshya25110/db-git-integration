# %%
spark

# %%
# REMOVE THE HARDCODED KEY. USE THIS:
spark.conf.set(
    "fs.azure.account.key.laksstorage25.dfs.core.windows.net",
    dbutils.secrets.get(scope="dbscope25", key="kyy-secret")
)

# %%
sales_df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("abfss://bronze@laksstorage25.dfs.core.windows.net/raw_data/sales_transactions.csv")

# %%
sales_df.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("janani_casestudy.bronze.transactions")

# %%
df_accounts = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("abfss://bronze@vasudatalake4.dfs.core.windows.net/raw_data/account_master.csv")

# %%
df_accounts.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("janani_casestudy.bronze.account")

# %%
df_customers = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("abfss://bronze@vasudatalake4.dfs.core.windows.net/raw_data/customer_master.csv")

# %%
df_customers.write.format("delta")\
    .mode("overwrite")\
        .saveAsTable("janani_casestudy.bronze.customer")

# %%
df_branch = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("abfss://bronze@vasudatalake4.dfs.core.windows.net/raw_data/branch_master.csv")

# %%
df_branch.write.format("delta")\
    .mode("overwrite")\
        .saveAsTable("janani_casestudy.bronze.branch")

# %%
df_alerts = spark.read.format("csv")\
    .option("header" , "true")\
        .option("inferSchema" , "true")\
            .load("abfss://bronze@vasudatalake4.dfs.core.windows.net/raw_data/alerts.csv")

# %%
df_alerts.write.format("delta")\
    .mode("overwrite")\
        .saveAsTable("janani_casestudy.bronze.alert")
